# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("coaster_db.csv") # DF = DataFrame
df.head()
# Out:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model  ...  speed1  \
# ...

# %%
df.shape
# Out:
# (1087, 56)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1087 entries, 0 to 1086
# Data columns (total 56 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   coaster_name                   1087 non-null   str
#  1   Length                         953 non-null    str
#  2   Speed                          937 non-null    str
#  3   Location                       1087 non-null   str
#  4   Status                         874 non-null    str
#  5   Opening date                   837 non-null    str
#  6   Type                           1087 non-null   str
#  7   Manufacturer                   1028 non-null   str
#  8   Height restriction             831 non-null    str
#  9   Model                          744 non-null    str
#  10  Height                         965 non-null    str
#  11  Inversions                     932 non-null    float64
#  12  Lift/launch system             795 non-null    str
# ...

# %%
df.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %%
df.isnull().sum()
# Out:
# coaster_name                        0
# Length                            134
# Speed                             150
# Location                            0
# Status                            213
# Opening date                      250
# Type                                0
# Manufacturer                       59
# Height restriction                256
# Model                             343
# Height                            122
# Inversions                        155
# Lift/launch system                292
# Cost                              705
# Trains                            369
# Park section                      600
# Duration                          322
# Capacity                          512
# G-force                           725
# Designer                          509
# Max vertical angle                730
# Drop                              593
# Soft opening date                 991
# Fast Lane available              1018
# Replaced                          914
# ...

# %%
df = df.drop(columns=[
    'Fast Lane available',
    'Soft opening date',
    'Cost',
    'Replaced'
])

# %%
df.shape
# Out:
# (1087, 52)

# %%
df[['speed_mph', 'height_ft', 'Gforce_clean']].isnull().sum()
# Out:
# speed_mph       150
# height_ft       916
# Gforce_clean    725
# dtype: int64

# %%
df = df.drop(columns=['height_ft', 'Gforce_clean'])
df.shape
# Out:
# (1087, 50)

# %%
df['speed_mph'].isnull().sum()
# Out:
# np.int64(150)

# %%
df['speed_mph'] = df['speed_mph'].fillna(df['speed_mph'].mean())

# %%
df['speed_mph'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.iloc[0:5] # iloc = integer location
# Out:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model  ... Type_Main  \
# ...

# %%
df.iloc[0:5, 0:3]
# Out:
#                              coaster_name          Length             Speed
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN

# %%
features = df[['speed_mph', 'Inversions_clean']]

# %%
features.head()
# Out:
#    speed_mph  Inversions_clean
# 0   6.000000                 0
# 1  48.617289                 1
# 2  48.617289                 0
# 3  48.617289                 1
# 4  48.617289                 1

# %%
tensor_data = tf.convert_to_tensor(features.values)
tensor_data.shape
# Out:
# TensorShape([1087, 2])

# %%
y = df['year_introduced']
y.head()
# Out:
# 0    1884
# 1    1895
# 2    1896
# 3    1901
# 4    1901
# Name: year_introduced, dtype: int64

# %%
y_tensor = tf.convert_to_tensor(y.values)
y_tensor.shape
# Out:
# TensorShape([1087])

# %%
reshaped_tensor = tf.reshape(tensor_data, (2, 1087))
reshaped_tensor.shape
# Out:
# TensorShape([2, 1087])

# %%
df['speed_per_inversion'] = df['speed_mph'] / (df['Inversions_clean'] + 1)
df[['speed_mph', 'Inversions_clean', 'speed_per_inversion']].head()
# Out:
#    speed_mph  Inversions_clean  speed_per_inversion
# 0   6.000000                 0             6.000000
# 1  48.617289                 1            24.308645
# 2  48.617289                 0            48.617289
# 3  48.617289                 1            24.308645
# 4  48.617289                 1            24.308645

# %%
new_feature_tensor = tf.convert_to_tensor(
    df['speed_per_inversion'].values
)
new_feature_tensor.shape
# Out:
# TensorShape([1087])
